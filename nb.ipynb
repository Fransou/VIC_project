# %%
import numpy as np

from skimage import io
import matplotlib.pyplot as plt

from main.filter import *
from main.visualize import *


PATH = 'raw-890/'

# %%
fig, axes = plt.subplots(4,3,figsize=(16,16))

for i in range(4):
    img = io.imread(PATH + f'{6+i}_img_.png')
    f_img = full_filter(img)
    depth = visualize_depth_v0(img)
    axes[i,0].imshow(img)
    axes[i,0].set_title('Original Image')
    axes[i,1].imshow(f_img)
    axes[i,1].set_title('Filtered Image')
    axes[i,2].imshow(depth, cmap='gray')
    axes[i,2].set_title('Depth Computed')
